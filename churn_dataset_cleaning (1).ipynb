# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("/content/Churn_Unclean_Project.xlsx")

# %%
df
# Out:
#     Customer_ID     Customer_Name  Gender    Age        State       City  \
# 0         C1000  Abhishek Jaiswal  Female   35.0  Maharashtra       Pune
# 1         C1001       Rohit Kumar    Male    NaN        Delhi      Noida
# 2         C1002       Pooja Singh  Female   42.0           UP     Kanpur
# 3         C1003               NaN    Male   59.0    Karnataka  Bengaluru
# 4         C1004       Mohit Arora   male    26.0      Gujarat  Ahmedabad
# ..          ...               ...     ...    ...          ...        ...
# 537       C5005        Sneha Jain  Female  115.0      Gujarat      Surat
# 538       C5006        Neha Verma  Female   18.0       Delhi       Noida
# 539       C5007       Vikas Yadav    Male   61.0        Delhi
# 540       C5008       Mohit Arora    Male   45.0      Gujarat  Ahmedabad
# 541       C5009       Rahul Singh    Male   25.0           UP     Kanpur
#
#      Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  \
# ...

# %%
df.head()
# Out:
#   Customer_ID     Customer_Name  Gender   Age        State       City  \
# 0       C1000  Abhishek Jaiswal  Female  35.0  Maharashtra       Pune
# 1       C1001       Rohit Kumar    Male   NaN        Delhi      Noida
# 2       C1002       Pooja Singh  Female  42.0           UP     Kanpur
# 3       C1003               NaN    Male  59.0    Karnataka  Bengaluru
# 4       C1004       Mohit Arora   male   26.0      Gujarat  Ahmedabad
#
#    Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  \
# 0           58.0             basic          1614.26       93273.08
# 1           36.0           Premium           429.60       15858.60
# 2           13.0             Basic           555.03        6869.39
# 3           55.0          Standard              NaN      101349.10
# 4            6.0           Premium           314.02        1926.12
#
#     Contract_Type Payment_Method Internet_Service Tech_Support Senior_Citizen  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 542 entries, 0 to 541
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer_ID            542 non-null    object
#  1   Customer_Name          533 non-null    object
#  2   Gender                 536 non-null    object
#  3   Age                    536 non-null    float64
#  4   State                  531 non-null    object
#  5   City                   539 non-null    object
#  6   Tenure_Months          534 non-null    float64
#  7   Subscription_Type      530 non-null    object
#  8   Monthly_Charges        529 non-null    float64
#  9   Total_Charges          533 non-null    float64
#  10  Contract_Type          538 non-null    object
#  11  Payment_Method         526 non-null    object
#  12  Internet_Service       535 non-null    object
#  13  Tech_Support           530 non-null    object
# ...

# %%
df.describe()
# Out:
#               Age  Tenure_Months  Monthly_Charges  Total_Charges
# count  536.000000     534.000000       529.000000     533.000000
# mean    44.399254      36.406367      1335.269206   49745.287336
# std     18.556837      20.669599       715.972838   41644.111657
# min      3.000000       1.000000     -2454.770000  -99781.820000
# 25%     30.000000      19.000000       756.570000   18770.290000
# 50%     44.000000      38.000000      1306.800000   40649.600000
# 75%     57.000000      54.000000      1900.650000   75647.400000
# max    165.000000      72.000000      2492.510000  171429.830000

# %%
df.shape
# Out:
# (542, 18)

# %%
df.isnull()
# Out:
#      Customer_ID  Customer_Name  Gender    Age  State   City  Tenure_Months  \
# 0          False          False   False  False  False  False          False
# 1          False          False   False   True  False  False          False
# 2          False          False   False  False  False  False          False
# 3          False           True   False  False  False  False          False
# 4          False          False   False  False  False  False          False
# ..           ...            ...     ...    ...    ...    ...            ...
# 537        False          False   False  False  False  False          False
# 538        False          False   False  False  False  False          False
# 539        False          False   False  False  False  False          False
# 540        False          False   False  False  False  False          False
# 541        False          False   False  False  False  False          False
#
# ...

# %%
df.isnull().sum()
# Out:
# Customer_ID               0
# Customer_Name             9
# Gender                    6
# Age                       6
# State                    11
# City                      3
# Tenure_Months             8
# Subscription_Type        12
# Monthly_Charges          13
# Total_Charges             9
# Contract_Type             4
# Payment_Method           16
# Internet_Service          7
# Tech_Support             12
# Senior_Citizen            8
# Dependents                3
# Churn                     4
# Last_Interaction_Date     3
# dtype: int64

# %%
#check duplicate record
df.duplicated().sum()
# Out:
# np.int64(7)

# %%
 # remove duplicate record     inplace mtlab real data me bhi chage hoga
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (535, 18)

# %%
#replace dirty values means reomve null or N/A value
df.replace(["N/A","NULL",""," "],np.nan,inplace=True)

# %%
df.isnull().sum()
# Out:
# Customer_ID               0
# Customer_Name             8
# Gender                    5
# Age                       6
# State                    10
# City                      5
# Tenure_Months             7
# Subscription_Type        11
# Monthly_Charges          12
# Total_Charges             8
# Contract_Type             3
# Payment_Method           15
# Internet_Service          6
# Tech_Support             11
# Senior_Citizen            7
# Dependents                2
# Churn                     3
# Last_Interaction_Date     2
# dtype: int64

# %%
#remove extra spaces
df=df.apply(lambda x:x.str.strip() if x.dtype=="object" else x)

# %%
df.head(1)
# Out:
#   Customer_ID     Customer_Name  Gender   Age        State  City  \
# 0       C1000  Abhishek Jaiswal  Female  35.0  Maharashtra  Pune
#
#    Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  \
# 0           58.0             basic          1614.26       93273.08
#
#   Contract_Type Payment_Method Internet_Service Tech_Support Senior_Citizen  \
# 0      One Year            UPI            Fiber          Yes             No
#
#   Dependents Churn Last_Interaction_Date
# 0        Yes    No            12-10-2025

# %%
#proper case
df["Customer_Name"]=df["Customer_Name"].str.title()
df["State"]=df["State"].str.title()
df["City"]=df["City"].str.title()
df["Subscription_Type"]=df["Subscription_Type"].str.title()
df["Contract_Type"]=df["Contract_Type"].str.title()

# %%
df["Subscription_Type"].value_counts()
# Out:
# Subscription_Type
# Premium     184
# Basic       171
# Standard    169
# Name: count, dtype: int64

# %%
df["Churn"].value_counts()
# Out:
# Churn
# No     405
# Yes    125
# YES      1
# yes      1
# Name: count, dtype: int64

# %%
df["Churn"]=df["Churn"].str.title()

# %%
df["Churn"].value_counts()
# Out:
# Churn
# No     405
# Yes    127
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 535 entries, 0 to 541
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer_ID            535 non-null    object
#  1   Customer_Name          527 non-null    object
#  2   Gender                 530 non-null    object
#  3   Age                    529 non-null    float64
#  4   State                  525 non-null    object
#  5   City                   530 non-null    object
#  6   Tenure_Months          528 non-null    float64
#  7   Subscription_Type      524 non-null    object
#  8   Monthly_Charges        523 non-null    float64
#  9   Total_Charges          527 non-null    float64
#  10  Contract_Type          532 non-null    object
#  11  Payment_Method         520 non-null    object
#  12  Internet_Service       529 non-null    object
#  13  Tech_Support           524 non-null    object
# ...

# %%
df.describe()
# Out:
#               Age  Tenure_Months  Monthly_Charges  Total_Charges
# count  529.000000     528.000000       523.000000     527.000000
# mean    44.328922      36.518939      1329.967285   49739.683890
# std     18.635396      20.659332       713.450173   41633.677902
# min      3.000000       1.000000     -2454.770000  -99781.820000
# 25%     30.000000      19.000000       757.420000   18818.270000
# 50%     44.000000      38.000000      1295.880000   40649.600000
# 75%     57.000000      54.000000      1879.020000   75126.770000
# max    165.000000      72.000000      2492.510000  171429.830000

# %%
# remove invalid age
df=df[(df["Age"]>=18)&(df["Age"]<=100)]

# %%
df.describe()
# Out:
#               Age  Tenure_Months  Monthly_Charges  Total_Charges
# count  492.000000     487.000000       492.000000     492.000000
# mean    43.191057      36.059548      1359.222033   50363.987561
# std     15.401619      20.465130       653.133221   39760.135287
# min     18.000000       1.000000       302.540000     354.120000
# 25%     30.000000      19.000000       762.940000   19129.100000
# 50%     43.000000      38.000000      1308.510000   40668.695000
# 75%     56.000000      53.000000      1889.437500   74393.410000
# max     70.000000      72.000000      2492.510000  171429.830000

# %%
df=df[df["Monthly_Charges"]>=0]
df=df[df["Total_Charges"]>=0]

# %%
df.shape
# Out:
# (492, 18)

# %%
# convert date
df["Last_Interaction_Date"]=pd.to_datetime(df["Last_Interaction_Date"],errors='coerce')

# %%
df["Tenure_Months"] = pd.to_numeric(df["Tenure_Months"], errors="coerce")

# %%
df["Tech_Support"] = df["Tech_Support"].fillna("No")
df["Payment_Method"] = df["Payment_Method"].fillna("Unknown")
df["Monthly_Charges"] = df["Monthly_Charges"].fillna(df["Monthly_Charges"].mean())
df["Tenure_Months"] = df["Tenure_Months"].fillna(df["Tenure_Months"].mean())
df['Age']=df['Age'].fillna(df['Age'].mean())

# %%
df["Last_Interaction_Date"]=df["Last_Interaction_Date"].fillna(df["Last_Interaction_Date" ].median())

# %%
# Feature Engineering
#customer lifetime value
df["Customer_Value"]=df["Monthly_Charges"]*df["Tenure_Months"]
df
# Out:
#     Customer_ID     Customer_Name  Gender   Age        State       City  \
# 0         C1000  Abhishek Jaiswal  Female  35.0  Maharashtra       Pune
# 2         C1002       Pooja Singh  Female  42.0           Up     Kanpur
# 4         C1004       Mohit Arora    male  26.0      Gujarat  Ahmedabad
# 6         C1006        Neha Verma  Female  18.0        Delhi      Noida
# 7         C1007       Vikas Yadav    Male  61.0        Delhi        NaN
# ..          ...               ...     ...   ...          ...        ...
# 534       C5002       Pooja Singh  Female  42.0           Up     Kanpur
# 536       C5004       Mohit Arora    male  26.0      Gujarat  Ahmedabad
# 538       C5006        Neha Verma  Female  18.0        Delhi      Noida
# 539       C5007       Vikas Yadav    Male  61.0        Delhi        NaN
# 540       C5008       Mohit Arora    Male  45.0      Gujarat  Ahmedabad
#
#      Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  \
# ...

# %%
#monthly revenue
df["Monthly_Revenue"]=df["Monthly_Charges"]

# %%
#tenure group "0-12","13-24","25-48","49-72"
bins=[0,12,24,48,72]
label=["0-12 month","13-24 month","25-48 month","49-72 month"]
df["Tenure_group"]=pd.cut(df["Tenure_Months"],bins=bins,labels=label)

# %%
df.head(10)
# Out:
#    Customer_ID     Customer_Name  Gender   Age        State       City  \
# 0        C1000  Abhishek Jaiswal  Female  35.0  Maharashtra       Pune
# 2        C1002       Pooja Singh  Female  42.0           Up     Kanpur
# 4        C1004       Mohit Arora    male  26.0      Gujarat  Ahmedabad
# 6        C1006        Neha Verma  Female  18.0        Delhi      Noida
# 7        C1007       Vikas Yadav    Male  61.0        Delhi        NaN
# 8        C1008       Mohit Arora    Male  45.0      Gujarat  Ahmedabad
# 10       C1010      Anjali Mehta    Male  60.0        Delhi      Delhi
# 14       C1014       Rahul Singh    Male  41.0    Karnataka     Mysuru
# 15       C1015       Pooja Singh    Male  50.0        Delhi      Noida
# 18       C1018       Amit Sharma     NaN  41.0      Gujarat  Ahmedabad
#
#     Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  ...  \
# 0            58.0             Basic          1614.26       93273.08  ...
# ...

# %%
#senior citizen flag
df["Senior_Flag"]=np.where(df["Age"]>=60,"Senior","Adult")

# %%
df
# Out:
#     Customer_ID     Customer_Name  Gender   Age        State       City  \
# 0         C1000  Abhishek Jaiswal  Female  35.0  Maharashtra       Pune
# 2         C1002       Pooja Singh  Female  42.0           Up     Kanpur
# 4         C1004       Mohit Arora    male  26.0      Gujarat  Ahmedabad
# 6         C1006        Neha Verma  Female  18.0        Delhi      Noida
# 7         C1007       Vikas Yadav    Male  61.0        Delhi        NaN
# ..          ...               ...     ...   ...          ...        ...
# 534       C5002       Pooja Singh  Female  42.0           Up     Kanpur
# 536       C5004       Mohit Arora    male  26.0      Gujarat  Ahmedabad
# 538       C5006        Neha Verma  Female  18.0        Delhi      Noida
# 539       C5007       Vikas Yadav    Male  61.0        Delhi        NaN
# 540       C5008       Mohit Arora    Male  45.0      Gujarat  Ahmedabad
#
#      Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  ...  \
# ...

# %%
# Churn Flag
df["Churn_Flag"]=df["Churn"].map({"Yes":1,"No":0})

# %%
df
# Out:
#     Customer_ID     Customer_Name  Gender   Age        State       City  \
# 0         C1000  Abhishek Jaiswal  Female  35.0  Maharashtra       Pune
# 2         C1002       Pooja Singh  Female  42.0           Up     Kanpur
# 4         C1004       Mohit Arora    male  26.0      Gujarat  Ahmedabad
# 6         C1006        Neha Verma  Female  18.0        Delhi      Noida
# 7         C1007       Vikas Yadav    Male  61.0        Delhi        NaN
# ..          ...               ...     ...   ...          ...        ...
# 534       C5002       Pooja Singh  Female  42.0           Up     Kanpur
# 536       C5004       Mohit Arora    male  26.0      Gujarat  Ahmedabad
# 538       C5006        Neha Verma  Female  18.0        Delhi      Noida
# 539       C5007       Vikas Yadav    Male  61.0        Delhi        NaN
# 540       C5008       Mohit Arora    Male  45.0      Gujarat  Ahmedabad
#
#      Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  ...  \
# ...

# %%
# Final  Check
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 492 entries, 0 to 540
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer_ID            492 non-null    object
#  1   Customer_Name          487 non-null    object
#  2   Gender                 488 non-null    object
#  3   Age                    492 non-null    float64
#  4   State                  485 non-null    object
#  5   City                   487 non-null    object
#  6   Tenure_Months          492 non-null    float64
#  7   Subscription_Type      486 non-null    object
#  8   Monthly_Charges        492 non-null    float64
#  9   Total_Charges          492 non-null    float64
#  10  Contract_Type          490 non-null    object
#  11  Payment_Method         492 non-null    object
#  12  Internet_Service       486 non-null    object
#  13  Tech_Support           492 non-null    object
# ...

# %%
df.describe()
# Out:
#               Age  Tenure_Months  Monthly_Charges  Total_Charges  \
# count  492.000000     492.000000       492.000000     492.000000
# mean    43.191057      36.059548      1359.222033   50363.987561
# min     18.000000       1.000000       302.540000     354.120000
# 25%     30.000000      19.000000       762.940000   19129.100000
# 50%     43.000000      37.000000      1308.510000   40668.695000
# 75%     56.000000      53.000000      1889.437500   74393.410000
# max     70.000000      72.000000      2492.510000  171429.830000
# std     15.401619      20.360662       653.133221   39760.135287
#
#                Last_Interaction_Date  Customer_Value  Monthly_Revenue  \
# count                            492      492.000000       492.000000
# mean   2025-09-05 13:10:14.634146304    50231.467233      1359.222033
# min              2025-01-01 00:00:00      379.700000       302.540000
# 25%              2025-08-24 00:00:00    19125.137500       762.940000
# ...

# %%
# Out:
#     Customer_ID     Customer_Name  Gender   Age        State       City  \
# 0         C1000  Abhishek Jaiswal  Female  35.0  Maharashtra       Pune
# 2         C1002       Pooja Singh  Female  42.0           Up     Kanpur
# 4         C1004       Mohit Arora    male  26.0      Gujarat  Ahmedabad
# 6         C1006        Neha Verma  Female  18.0        Delhi      Noida
# 7         C1007       Vikas Yadav    Male  61.0        Delhi        NaN
# ..          ...               ...     ...   ...          ...        ...
# 534       C5002       Pooja Singh  Female  42.0           Up     Kanpur
# 536       C5004       Mohit Arora    male  26.0      Gujarat  Ahmedabad
# 538       C5006        Neha Verma  Female  18.0        Delhi      Noida
# 539       C5007       Vikas Yadav    Male  61.0        Delhi        NaN
# 540       C5008       Mohit Arora    Male  45.0      Gujarat  Ahmedabad
#
#      Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# Customer_ID              0
# Customer_Name            5
# Gender                   4
# Age                      0
# State                    7
# City                     5
# Tenure_Months            0
# Subscription_Type        6
# Monthly_Charges          0
# Total_Charges            0
# Contract_Type            2
# Payment_Method           0
# Internet_Service         6
# Tech_Support             0
# Senior_Citizen           6
# Dependents               1
# Churn                    2
# Last_Interaction_Date    0
# Customer_Value           0
# Monthly_Revenue          0
# Tenure_group             0
# Senior_Flag              0
# Churn_Flag               2
# dtype: int64

# %%
categorical_cols = [
    "Customer_Name",
    "Gender",
    "State",
    "City",
    "Subscription_Type",
    "Contract_Type",
    "Payment_Method",
    "Internet_Service",
    "Senior_Citizen",
    "Dependents"


]

df[categorical_cols] = df[categorical_cols].fillna("Unknown")

# %%
df.isnull().sum()
# Out:
# Customer_ID              0
# Customer_Name            0
# Gender                   0
# Age                      0
# State                    0
# City                     0
# Tenure_Months            0
# Subscription_Type        0
# Monthly_Charges          0
# Total_Charges            0
# Contract_Type            0
# Payment_Method           0
# Internet_Service         0
# Tech_Support             0
# Senior_Citizen           0
# Dependents               0
# Churn                    2
# Last_Interaction_Date    0
# Customer_Value           0
# Monthly_Revenue          0
# Tenure_group             0
# Senior_Flag              0
# Churn_Flag               2
# dtype: int64

# %%
df = df.dropna(subset=["Churn"])

# %%
df.isnull().sum()
# Out:
# Customer_ID              0
# Customer_Name            0
# Gender                   0
# Age                      0
# State                    0
# City                     0
# Tenure_Months            0
# Subscription_Type        0
# Monthly_Charges          0
# Total_Charges            0
# Contract_Type            0
# Payment_Method           0
# Internet_Service         0
# Tech_Support             0
# Senior_Citizen           0
# Dependents               0
# Churn                    0
# Last_Interaction_Date    0
# Customer_Value           0
# Monthly_Revenue          0
# Tenure_group             0
# Senior_Flag              0
# Churn_Flag               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Step 1: Customer Overview
print("Total Customers:", df["Customer_ID"].nunique())
print("Total Revenue:",df["Total_Charges"].sum())
print("Average Monthly Charges:",df["Monthly_Charges"].mean())
print("Average Customer Value:",df["Customer_Value"].mean())
print("Average Tenure:",df["Tenure_Months"].mean())
# Out:
# Total Customers: 489
# Total Revenue: 24586608.18
# Average Monthly Charges: 1358.47393877551
# Average Customer Value: 50042.75342626661
# Average Tenure: 35.97407702300632

# %%
df.describe()
# Out:
#               Age  Tenure_Months  Monthly_Charges  Total_Charges  \
# count  490.000000     490.000000       490.000000     490.000000
# mean    43.212245      35.974077      1358.473939   50176.751388
# min     18.000000       1.000000       302.540000     354.120000
# 25%     30.000000      19.000000       763.447500   19047.500000
# 50%     43.000000      37.000000      1308.510000   40668.695000
# 75%     56.000000      53.000000      1884.297500   74017.605000
# max     70.000000      72.000000      2492.510000  171429.830000
# std     15.428304      20.349939       651.539802   39492.365374
#
#                Last_Interaction_Date  Customer_Value  Monthly_Revenue  \
# count                            490      490.000000       490.000000
# mean   2025-09-05 18:24:58.775510272    50042.753426      1358.473939
# min              2025-01-01 00:00:00      379.700000       302.540000
# 25%              2025-08-24 00:00:00    19108.912500       763.447500
# ...

# %%
df["Churn"].value_counts()
# Out:
# Churn
# No     374
# Yes    116
# Name: count, dtype: int64

# %%
df["Churn"].value_counts(normalize=True)*100
# Out:
# Churn
# No     76.326531
# Yes    23.673469
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
Step 2: Churn Analysis
df["Churn"].value_counts().plot(
    kind="bar",
    title="Customer Churn Distribution"
)
plt.xlabel("Churn")
plt.ylabel("Num Of Customers")
plt.show()

# %%
pd.crosstab(
    df["Contract_Type"],
    df["Churn"],
    normalize="index"
) * 100
# Out:
# Churn                   No        Yes
# Contract_Type
# Month-To-Month   78.770950  21.229050
# One Year         76.582278  23.417722
# Two Year         72.847682  27.152318
# Unknown         100.000000   0.000000

# %%
#Step 3: Churn by Contract Type
pd.crosstab(
    df["Contract_Type"],
    df["Churn"]
).plot(kind="bar")

plt.title("Churn by Contract Type")
plt.xlabel("Contract Type")
plt.ylabel("Number of Customer")
plt.xticks(rotation=0)
plt.show()

# %%
df.groupby("Churn")["Tenure_Months"].mean()
# Out:
# Churn
# No     37.072511
# Yes    32.432575
# Name: Tenure_Months, dtype: float64

# %%
#Step 4: Churn vs Tenure
df.boxplot(
   column="Tenure_Months",
    by="Churn"
)
plt.title("Tenure Distribution by Churn")
plt.suptitle("")
plt.xlabel("Churn")
plt.ylabel("Tenure(Months)")
plt.show()

# %%
#Step 5: Churn vs Monthly Charges
df.groupby("Churn")["Monthly_Charges"].mean()
# Out:
# Churn
# No     1361.181471
# Yes    1349.744483
# Name: Monthly_Charges, dtype: float64

# %%
df.boxplot(
    column="Monthly_Charges",
    by="Churn"
)
plt.title("Monthly Charges by Churn")
plt.suptitle("")
plt.xlabel("Churn")
plt.ylabel("Montly Charges")
plt.show()

# %%
#Step 6: Churn by Subscription Type
pd.crosstab(
    df["Subscription_Type"],
    df["Churn"],
    normalize="index"
)*100
# Out:
# Churn                     No        Yes
# Subscription_Type
# Basic              83.660131  16.339869
# Premium            73.372781  26.627219
# Standard           72.222222  27.777778
# Unknown            83.333333  16.666667

# %%
#Step 7: Churn by Tech Support
pd.crosstab(
    df["Tech_Support"],
    df["Churn"],
    normalize="index"

)*100
# Out:
# Churn                No        Yes
# Tech_Support
# No            76.717557  23.282443
# Yes           75.877193  24.122807

# %%
#Step 8: Customer Lifetime Value
df["Customer_Value"] = (
    df["Monthly_Charges"] * df["Tenure_Months"]
)
# Out:
# /tmp/ipykernel_2501/950634395.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Customer_Value"] = (

# %%
df.groupby("Churn")["Customer_Value"].mean()
# Out:
# Churn
# No     1.913015e+07
# Yes    5.390796e+06
# Name: Customer_Value, dtype: float64

# %%
df.groupby("Churn")["Customer_Value"].sum()
# Out:
# Churn
# No     1.913015e+07
# Yes    5.390796e+06
# Name: Customer_Value, dtype: float64

# %%
#Step 9: Correlation Analysis
numeric_cols = [
    "Age",
    "Tenure_Months",
    "Monthly_Charges",
    "Total_Charges",
    "Customer_Value",
    "Monthly_Revenue"
]

df[numeric_cols].corr()
# Out:
#                       Age  Tenure_Months  Monthly_Charges  Total_Charges  \
# Age              1.000000      -0.013640        -0.059594      -0.064125
# Tenure_Months   -0.013640       1.000000         0.088643       0.737469
# Monthly_Charges -0.059594       0.088643         1.000000       0.642619
# Total_Charges   -0.064125       0.737469         0.642619       1.000000
# Customer_Value  -0.061901       0.739585         0.641949       0.998574
# Monthly_Revenue -0.059594       0.088643         1.000000       0.642619
#
#                  Customer_Value  Monthly_Revenue
# Age                   -0.061901        -0.059594
# Tenure_Months          0.739585         0.088643
# Monthly_Charges        0.641949         1.000000
# Total_Charges          0.998574         0.642619
# Customer_Value         1.000000         0.641949
# Monthly_Revenue        0.641949         1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

sns.heatmap(
    df[numeric_cols].corr(),
    annot=True,
    cmap="coolwarm"
)

plt.title("Correlation Matrix")
plt.show()

# %%
contract_churn = pd.crosstab(
    df["Contract_Type"],
    df["Churn"],
    normalize="index"
) * 100

contract_churn
# Out:
# Churn                   No        Yes
# Contract_Type
# Month-To-Month   78.770950  21.229050
# One Year         76.582278  23.417722
# Two Year         72.847682  27.152318
# Unknown         100.000000   0.000000

# %%
df.to_csv("customer_churn_cleaned.csv", index=False)
